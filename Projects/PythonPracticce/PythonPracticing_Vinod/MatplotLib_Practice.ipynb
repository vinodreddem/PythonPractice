# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
fig = plt.figure()
ax = fig.add_subplot(111) # here we can use separation for the axis if values is greater than 9(two digits)
plt.show()

#here 'F' is not the correct one , we need to keep small 'f'

# %%
fig = plt.figure()
ax = fig.add_subplot(9,9,2)
plt.show()

# %%
# setting the title and xlabel , y label etc...
fig2 = plt.figure(figsize=(10,10))
ax1 =fig2.add_subplot(1,1,1)
ax1.set(
    title ='My First plot',
    xlabel ='X-Axis ',
    ylabel ='Y -Axis ',
    xlim = (0,5), 
    ylim=(0,5)
)
plt.show()

# %%
# Plotting two axis in single figure -Needs to check how to display

# %%
fig3 = plt.figure(figsize=(10,10))
ax3 =fig3.add_subplot(2,2,2)
ax3.set(
    title ='My First plot',
    xlabel ='X-Axis ',
    ylabel ='Y -Axis ',
    xlim = (0,5), 
    ylim=(0,5)
)

ax2 =fig3.add_subplot(2,2,2)
ax2.set(
    title ='My Second  plot',
    xlabel ='X-Axis ',
    ylabel ='Y -Axis ',
    xlim = (0,5), 
    ylim=(0,5)
)
ax3.plot()

ax2.plot()
plt.show()
# Out:
# C:\Users\Sanvi\Anaconda3\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
fig3 = plt.figure(figsize=(10,10))
ax3 =fig3.add_subplot(2,2,2)
ax3.set(
    title ='My First plot',
    xlabel ='X-Axis ',
    ylabel ='Y -Axis ',
    xlim = (1,5), 
    ylim=(1,5)
)
x=[1,2,3,4,5]
y=[5,4,3,2,1]
ax3.plot(x,y)
plt.show()

# %%
#Plotting data or setting attributes can also be done by calling functions like plot, and title directly on plt.

fig = plt.figure(figsize=(8,6))
x = [1, 2, 3, 4]; y = [2, 4, 6, 8]
plt.plot(x, y)
plt.title('My First Plot')
plt.xlabel('X-Axis'); plt.ylabel('Y-Axis')
plt.xlim(0,5); plt.ylim(0,10)
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Line Plot

# %%
# Line PLot 
#plot function is used to draw the line plot function.

x=[1,5,7,9]
y=[4,5,4,8]
fig_line = plt.figure()
ax = fig_line.add_subplot(111)
ax.plot(x,y)

# %% [markdown]
# Common Parameters of 'plot' Function
# color: Sets the color of the line.
#
# linestyle: Sets the line style, e.g., solid, dashed, etc.
#
# linewidth: Sets the thickness of a line.
#
# marker: Chooses a marker for data points, e.g., circle, triangle, etc.
#
# markersize: Sets the size of the chosen marker.
#
# label: Names the line, which will come in legend.

# %% [markdown]
# ### Subplots

# %%
# subplot () -function is used to create the subplots 
fig_subplot = plt.figure(figsize=(10,8))
axes1 = plt.subplot(2,2,1,title='First PLot')
axes1.set_xticks([]); axes1.set_yticks([0.5,0.7])
axes2 = plt.subplot(2,2,2,title ="Second Plot")
axes3 =plt.subplot(2,2,3,title ="Third Plot")
axes4 =plt.subplot(2,2,4,title ="Fourth Plot")

plt.show()

# %%
# subplot () -function is used to create the subplots 
fig_subplot = plt.figure(figsize=(10,8))
axes1 = plt.subplot(2,2,1,title='First PLot') #this is not going to dispplay since  this is going to ovveride with second plot,
#index is same for both 
axes2 = plt.subplot(2,2,1,title ="Second Plot")
axes3 =plt.subplot(2,2,3,title ="Third Plot")
axes4 =plt.subplot(2,2,4,title ="Fourth Plot")

plt.show()

# %%
# subplot () -function is used to create the subplots 
fig_subplot = plt.figure(figsize=(10,8))
axes1 = plt.subplot(2,2,1,title='First PLot')
axes2 = plt.subplot(2,4,2,title ="Second Plot")
axes3 =plt.subplot(2,4,6,title ="Third Plot")
axes4 =plt.subplot(2,4,4,title ="Fourth Plot")

plt.show()

#it is good practice to have a same number at rows and col values to have a perfect pictures b

# %%
np.random.seed(20)
plt.plot(np.random.randn(50).cumsum())

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25])
plt.show()

# %%
x=[1,2,3,4]
y=[1,4,9,16]
plt.plot(x,y)
plt.title('Using Plt Not Axis ')
plt.xlabel("Numbers")
plt.ylabel("Squrews")
plt.show()
