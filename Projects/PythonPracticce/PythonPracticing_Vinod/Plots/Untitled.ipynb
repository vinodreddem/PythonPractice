# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Draw simple figure 
arr = np.arange(10)
plt.plot(arr)

# %%
#draw plot using figure and axis,So here totally 4 sub plots possible (2 by 2)
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
plt.plot([4,6,8,10]) #If we use plotting command here ,
#matplotlib drwas on the last figure and subplot is used
plt.plot(np.random.randn(50).cumsum(),'k--')

# %%
#If we want to plot figures on ax1 and ax2 , then we need to use the 
#return object by fig.add_subplot()i.e ax1, ax2 direclty

ax1.hist(np.random.rand(100),bins=20,color='k',alpha=0.3)
ax2.scatter(np.arange(10),np.arange(10)*3)
